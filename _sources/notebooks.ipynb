# %% [markdown]
# ## tugas pertama pendata

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# $g(x, \mu, \sigma)=\frac{1}{\sqrt{2 \pi} \sigma} e^{-\frac{(x-\mu)^2}{2 \sigma^2}}$
#
# Anda belajar sintak latex

# %% [markdown]
# Untuk menghitung jarak diperlukan euclidian distance dengan rumus
#
# $$ d(p, q)=\sqrt{\left(q_1-p_1\right)^2+\left(q_2-p_2\right)^2}$$

# %% [markdown]
# $$ \operatorname{Pr}(R=T \mid G=T)=\frac{\operatorname{Pr}(G=T, R=T)}{\operatorname{Pr}(G=T)}=\frac{\sum_{x \in\{T, F\}} \operatorname{Pr}(G=T, S=x, R=T)}{\sum_{x, y \in\{T, F\}} \operatorname{Pr}(G=T, S=x, R=y)} $$
